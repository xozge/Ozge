# %% [markdown]
# # DATA CLEANING MISSING VALUE

# %% [markdown]
# Bu ödevde ABD Eğitim Sistemi'ne ait bir takım verileri inceleyeceksiniz. Öncelikle veri kümesini Kaggle'dan indirin. Burada eğitim sistemine ait bir çok veri kümesi bulunmaktadır. Bu ödevde 'states_all.csv' isimli veri kümesini kullanacaksınız.
#
# Bu ödevi tamamlamak için, aşağıdaki soruların çözümlerini içeren Jupyter notebook dosyasının Github linkini gönderin. Kafanıza takılan konuları mentörünüzle konuşabilir ya da ofis saatinde Slack üzerinden sorabilirsiniz.
#
# Veri kümesinde yer alan değişkenlerinin tiplerini ve her bir değişkenin eksik (null) değer oranını bulun.
#
# Verimizde yıl (year) sütunu olduğunu farketmişsinizdir. Şimdilik yıl verisini unutun ve her bir gözlemin aynı yıl içerisinde yapıldığını farz edin. Her bir değişken için eksik değerleri nasıl doldurabileceğinizi düşünün. Eksik değerleri bir değerle doldurmak hangi değişkenler için anlamlı, hangileri için anlamsızdır?
#
# Şimdi zaman faktörünü dikkate alma zamanı! 2. sorudaki cevabınızı tekrar gözden geçirin ve eksik verileri o yıl içerisinde gözlemlenen değerlere dayanarak doldurun. Örneğin, bir değeri ortalama değer ile doldurmak isterseniz, o yılın ortalamasını hesaplayın.
#
# Bu sefer, eksik değerleri enterpolasyon yaparak doldurun.
#
# İkinci, üçüncü ve dördüncü sorulardaki cevaplarınızı karşılaştırın. Anlamlı bir fark görebiliyor musunuz?
#
# In this assignment, you are going to use a dataset related to the US education system. Please download the (dataset) from Kaggle. You are going to use states_all.csv within this dataset.

# %% [markdown]
# **1. Find the types of variables in the dataset and the missing (null) ratio of each variable.**

# %%
import numpy as np
import pandas as pd

# %%
us_data=pd.read_csv("states_all.csv")
us_data
# Out:
#              PRIMARY_KEY          STATE  YEAR  ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992     NaN      2678885.0
# 1            1992_ALASKA         ALASKA  1992     NaN      1049591.0
# 2           1992_ARIZONA        ARIZONA  1992     NaN      3258079.0
# 3          1992_ARKANSAS       ARKANSAS  1992     NaN      1711959.0
# 4        1992_CALIFORNIA     CALIFORNIA  1992     NaN     26260025.0
# ...                  ...            ...   ...     ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019     NaN            NaN
# 1711     2019_WASHINGTON     WASHINGTON  2019     NaN            NaN
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019     NaN            NaN
# 1713      2019_WISCONSIN      WISCONSIN  2019     NaN            NaN
# 1714        2019_WYOMING        WYOMING  2019     NaN            NaN
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# ...

# %%
us_data1=us_data.copy()
us_data2=us_data.copy()
us_data3=us_data.copy()

# %%
us_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1715 entries, 0 to 1714
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   PRIMARY_KEY                   1715 non-null   object
#  1   STATE                         1715 non-null   object
#  2   YEAR                          1715 non-null   int64
#  3   ENROLL                        1224 non-null   float64
#  4   TOTAL_REVENUE                 1275 non-null   float64
#  5   FEDERAL_REVENUE               1275 non-null   float64
#  6   STATE_REVENUE                 1275 non-null   float64
#  7   LOCAL_REVENUE                 1275 non-null   float64
#  8   TOTAL_EXPENDITURE             1275 non-null   float64
#  9   INSTRUCTION_EXPENDITURE       1275 non-null   float64
#  10  SUPPORT_SERVICES_EXPENDITURE  1275 non-null   float64
#  11  OTHER_EXPENDITURE             1224 non-null   float64
# ...

# %%
us_data.isnull().sum()
# Out:
# PRIMARY_KEY                        0
# STATE                              0
# YEAR                               0
# ENROLL                           491
# TOTAL_REVENUE                    440
# FEDERAL_REVENUE                  440
# STATE_REVENUE                    440
# LOCAL_REVENUE                    440
# TOTAL_EXPENDITURE                440
# INSTRUCTION_EXPENDITURE          440
# SUPPORT_SERVICES_EXPENDITURE     440
# OTHER_EXPENDITURE                491
# CAPITAL_OUTLAY_EXPENDITURE       440
# GRADES_PK_G                      173
# GRADES_KG_G                       83
# GRADES_4_G                        83
# GRADES_8_G                        83
# GRADES_12_G                       83
# GRADES_1_8_G                     695
# GRADES_9_12_G                    644
# GRADES_ALL_G                      83
# AVG_MATH_4_SCORE                1150
# AVG_MATH_8_SCORE                1113
# AVG_READING_4_SCORE             1065
# AVG_READING_8_SCORE             1153
# dtype: int64

# %%
us_data.isnull().sum()*100/us_data.shape[0]
# Out:
# PRIMARY_KEY                      0.000000
# STATE                            0.000000
# YEAR                             0.000000
# ENROLL                          28.629738
# TOTAL_REVENUE                   25.655977
# FEDERAL_REVENUE                 25.655977
# STATE_REVENUE                   25.655977
# LOCAL_REVENUE                   25.655977
# TOTAL_EXPENDITURE               25.655977
# INSTRUCTION_EXPENDITURE         25.655977
# SUPPORT_SERVICES_EXPENDITURE    25.655977
# OTHER_EXPENDITURE               28.629738
# CAPITAL_OUTLAY_EXPENDITURE      25.655977
# GRADES_PK_G                     10.087464
# GRADES_KG_G                      4.839650
# GRADES_4_G                       4.839650
# GRADES_8_G                       4.839650
# GRADES_12_G                      4.839650
# GRADES_1_8_G                    40.524781
# GRADES_9_12_G                   37.551020
# GRADES_ALL_G                     4.839650
# AVG_MATH_4_SCORE                67.055394
# ...

# %% [markdown]
# **2.You may have noticed that our data has a year column. For now, forget about the year data and assume that each observation was made in the same year. Consider how you can fill in missing values for each variable. Filling in the missing values with a value is meaningful for which variables and for which ones?**

# %%
us_data.groupby("STATE")["ENROLL"].mean()
# Out:
# STATE
# ALABAMA                 7.365843e+05
# ALASKA                  1.304296e+05
# ARIZONA                 8.743221e+05
# ARKANSAS                4.519019e+05
# CALIFORNIA              5.945343e+06
# COLORADO                7.515678e+05
# CONNECTICUT             5.231307e+05
# DELAWARE                1.136383e+05
# DISTRICT_OF_COLUMBIA    6.199808e+04
# DODEA                            NaN
# FLORIDA                 2.486441e+06
# GEORGIA                 1.503696e+06
# HAWAII                  1.834175e+05
# IDAHO                   2.555033e+05
# ILLINOIS                2.026003e+06
# INDIANA                 1.000065e+06
# IOWA                    4.937421e+05
# KANSAS                  4.727478e+05
# KENTUCKY                6.490130e+05
# LOUISIANA               7.166416e+05
# MAINE                   1.983767e+05
# MARYLAND                8.419581e+05
# MASSACHUSETTS           9.318566e+05
# MICHIGAN                1.594491e+06
# MINNESOTA               8.157256e+05
# ...

# %%
us_data1["ENROLL"]=us_data1["ENROLL"].fillna(us_data1.groupby("STATE")["ENROLL"].transform("mean"))
us_data1["ENROLL"]=us_data1["ENROLL"].fillna(us_data1["ENROLL"].mean())

# %%
us_data1["TOTAL_REVENUE"]=us_data1["TOTAL_REVENUE"].fillna(us_data1.groupby("STATE")["TOTAL_REVENUE"].transform("mean"))
us_data1["TOTAL_REVENUE"]=us_data1["TOTAL_REVENUE"].fillna(us_data1["TOTAL_REVENUE"].mean())

# %%
us_data1["FEDERAL_REVENUE"]=us_data1["FEDERAL_REVENUE"].fillna(us_data1.groupby("STATE")["FEDERAL_REVENUE"].transform("mean"))
us_data1["FEDERAL_REVENUE"]=us_data1["FEDERAL_REVENUE"].fillna(us_data1["FEDERAL_REVENUE"].mean())

# %%
us_data1["STATE_REVENUE"]=us_data1["STATE_REVENUE"].fillna(us_data1.groupby("STATE")["STATE_REVENUE"].transform("mean"))
us_data1["STATE_REVENUE"]=us_data1["STATE_REVENUE"].fillna(us_data1["STATE_REVENUE"].mean())

# %%
us_data1["LOCAL_REVENUE"]=us_data1["LOCAL_REVENUE"].fillna(us_data1.groupby("STATE")["LOCAL_REVENUE"].transform("mean"))
us_data1["LOCAL_REVENUE"]=us_data1["LOCAL_REVENUE"].fillna(us_data1["LOCAL_REVENUE"].mean())

# %%
us_data1["TOTAL_EXPENDITURE"]=us_data1["TOTAL_EXPENDITURE"].fillna(us_data1.groupby("STATE")["TOTAL_EXPENDITURE"].transform("mean"))
us_data1["TOTAL_EXPENDITURE"]=us_data1["TOTAL_EXPENDITURE"].fillna(us_data1["TOTAL_EXPENDITURE"].mean())

# %%
us_data1["INSTRUCTION_EXPENDITURE"]=us_data1["INSTRUCTION_EXPENDITURE"].fillna(us_data1.groupby("STATE")["INSTRUCTION_EXPENDITURE"].transform("mean"))
us_data1["INSTRUCTION_EXPENDITURE"]=us_data1["INSTRUCTION_EXPENDITURE"].fillna(us_data1["INSTRUCTION_EXPENDITURE"].mean())

# %%
us_data1["SUPPORT_SERVICES_EXPENDITURE"]=us_data1["SUPPORT_SERVICES_EXPENDITURE"].fillna(us_data1.groupby("STATE")["SUPPORT_SERVICES_EXPENDITURE"].transform("mean"))
us_data1["SUPPORT_SERVICES_EXPENDITURE"]=us_data1["SUPPORT_SERVICES_EXPENDITURE"].fillna(us_data1["SUPPORT_SERVICES_EXPENDITURE"].mean())

# %%
us_data1["OTHER_EXPENDITURE"]=us_data1["OTHER_EXPENDITURE"].fillna(us_data1.groupby("STATE")["OTHER_EXPENDITURE"].transform("mean"))
us_data1["OTHER_EXPENDITURE"]=us_data1["OTHER_EXPENDITURE"].fillna(us_data1["OTHER_EXPENDITURE"].mean())

# %%
us_data1["CAPITAL_OUTLAY_EXPENDITURE"]=us_data1["CAPITAL_OUTLAY_EXPENDITURE"].fillna(us_data1.groupby("STATE")["CAPITAL_OUTLAY_EXPENDITURE"].transform("mean"))
us_data1["CAPITAL_OUTLAY_EXPENDITURE"]=us_data1["CAPITAL_OUTLAY_EXPENDITURE"].fillna(us_data1["CAPITAL_OUTLAY_EXPENDITURE"].mean())

# %%
us_data1["GRADES_PK_G"]=us_data1["GRADES_PK_G"].fillna(us_data1.groupby("STATE")["GRADES_PK_G"].transform("mean"))
us_data1["GRADES_PK_G"]=us_data1["GRADES_PK_G"].fillna(us_data1["GRADES_PK_G"].mean())

# %%
us_data1["GRADES_KG_G"]=us_data1["GRADES_KG_G"].fillna(us_data1.groupby("STATE")["GRADES_KG_G"].transform("mean"))
us_data1["GRADES_KG_G"]=us_data1["GRADES_KG_G"].fillna(us_data1["GRADES_KG_G"].mean())

# %%
us_data1["GRADES_4_G"]=us_data1["GRADES_4_G"].fillna(us_data1.groupby("STATE")["GRADES_4_G"].transform("mean"))
us_data1["GRADES_4_G"]=us_data1["GRADES_4_G"].fillna(us_data1["GRADES_4_G"].mean())

# %%
us_data1["GRADES_8_G"]=us_data1["GRADES_8_G"].fillna(us_data1.groupby("STATE")["GRADES_8_G"].transform("mean"))
us_data1["GRADES_8_G"]=us_data1["GRADES_8_G"].fillna(us_data1["GRADES_8_G"].mean())

# %%
us_data1["GRADES_12_G"]=us_data1["GRADES_12_G"].fillna(us_data1.groupby("STATE")["GRADES_12_G"].transform("mean"))
us_data1["GRADES_12_G"]=us_data1["GRADES_12_G"].fillna(us_data1["GRADES_12_G"].mean())

# %%
us_data1["GRADES_1_8_G"]=us_data1["GRADES_1_8_G"].fillna(us_data1.groupby("STATE")["GRADES_1_8_G"].transform("mean"))
us_data1["GRADES_1_8_G"]=us_data1["GRADES_1_8_G"].fillna(us_data1["GRADES_1_8_G"].mean())

# %%
us_data1["GRADES_9_12_G"]=us_data1["GRADES_9_12_G"].fillna(us_data1.groupby("STATE")["GRADES_9_12_G"].transform("mean"))
us_data1["GRADES_9_12_G"]=us_data1["GRADES_9_12_G"].fillna(us_data1["GRADES_9_12_G"].mean())

# %%
us_data1["GRADES_ALL_G"]=us_data1["GRADES_ALL_G"].fillna(us_data1.groupby("STATE")["GRADES_ALL_G"].transform("mean"))
us_data1["GRADES_ALL_G"]=us_data1["GRADES_ALL_G"].fillna(us_data1["GRADES_ALL_G"].mean())

# %%
us_data1["AVG_MATH_4_SCORE"]=us_data1["AVG_MATH_4_SCORE"].fillna(us_data1.groupby("STATE")["AVG_MATH_4_SCORE"].transform("mean"))
us_data1["AVG_MATH_4_SCORE"]=us_data1["AVG_MATH_4_SCORE"].fillna(us_data1["AVG_MATH_4_SCORE"].mean())

# %%
us_data1["AVG_MATH_8_SCORE"]=us_data1["AVG_MATH_8_SCORE"].fillna(us_data1.groupby("STATE")["AVG_MATH_8_SCORE"].transform("mean"))
us_data1["AVG_MATH_8_SCORE"]=us_data1["AVG_MATH_8_SCORE"].fillna(us_data1["AVG_MATH_8_SCORE"].mean())

# %%
us_data1["AVG_READING_4_SCORE"]=us_data1["AVG_READING_4_SCORE"].fillna(us_data1.groupby("STATE")["AVG_READING_4_SCORE"].transform("mean"))
us_data1["AVG_READING_4_SCORE"]=us_data1["AVG_READING_4_SCORE"].fillna(us_data1["AVG_READING_4_SCORE"].mean())

# %%
us_data1["AVG_READING_8_SCORE"]=us_data1["AVG_READING_8_SCORE"].fillna(us_data1.groupby("STATE")["AVG_READING_8_SCORE"].transform("mean"))
us_data1["AVG_READING_8_SCORE"]=us_data1["AVG_READING_8_SCORE"].fillna(us_data1["AVG_READING_8_SCORE"].mean())

# %%
us_data1.isnull().sum()
# Out:
# PRIMARY_KEY                     0
# STATE                           0
# YEAR                            0
# ENROLL                          0
# TOTAL_REVENUE                   0
# FEDERAL_REVENUE                 0
# STATE_REVENUE                   0
# LOCAL_REVENUE                   0
# TOTAL_EXPENDITURE               0
# INSTRUCTION_EXPENDITURE         0
# SUPPORT_SERVICES_EXPENDITURE    0
# OTHER_EXPENDITURE               0
# CAPITAL_OUTLAY_EXPENDITURE      0
# GRADES_PK_G                     0
# GRADES_KG_G                     0
# GRADES_4_G                      0
# GRADES_8_G                      0
# GRADES_12_G                     0
# GRADES_1_8_G                    0
# GRADES_9_12_G                   0
# GRADES_ALL_G                    0
# AVG_MATH_4_SCORE                0
# AVG_MATH_8_SCORE                0
# AVG_READING_4_SCORE             0
# AVG_READING_8_SCORE             0
# dtype: int64

# %%
us_data1
# Out:
#              PRIMARY_KEY          STATE  YEAR        ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992  7.365843e+05     2678885.00
# 1            1992_ALASKA         ALASKA  1992  1.304296e+05     1049591.00
# 2           1992_ARIZONA        ARIZONA  1992  8.743221e+05     3258079.00
# 3          1992_ARKANSAS       ARKANSAS  1992  4.519019e+05     1711959.00
# 4        1992_CALIFORNIA     CALIFORNIA  1992  5.945343e+06    26260025.00
# ...                  ...            ...   ...           ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019  1.179632e+06    11237280.32
# 1711     2019_WASHINGTON     WASHINGTON  2019  1.010687e+06     9295918.12
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019  2.891283e+05     2664419.00
# 1713      2019_WISCONSIN      WISCONSIN  2019  8.671074e+05     8944846.84
# 1714        2019_WYOMING        WYOMING  2019  9.166442e+04     1173952.68
#
# ...

# %% [markdown]
# **3.Now it's time to consider the factor of time! Review your answer in question 2 and fill in the missing data based on the values observed during that year. For example, if you want to fill a value with an average value, calculate the average of that year.**

# %%
us_data2["ENROLL"]=us_data2["ENROLL"].fillna(us_data2.groupby("YEAR")["ENROLL"].transform("mean"))
us_data2["ENROLL"]=us_data2["ENROLL"].fillna(us_data2["ENROLL"].mean())

# %%
us_data2["TOTAL_REVENUE"]=us_data2["TOTAL_REVENUE"].fillna(us_data2.groupby("YEAR")["TOTAL_REVENUE"].transform("mean"))
us_data2["TOTAL_REVENUE"]=us_data2["TOTAL_REVENUE"].fillna(us_data2["TOTAL_REVENUE"].mean())

# %%
us_data2["FEDERAL_REVENUE"]=us_data2["FEDERAL_REVENUE"].fillna(us_data2.groupby("YEAR")["FEDERAL_REVENUE"].transform("mean"))
us_data2["FEDERAL_REVENUE"]=us_data2["FEDERAL_REVENUE"].fillna(us_data2["FEDERAL_REVENUE"].mean())

# %%
us_data2["STATE_REVENUE"]=us_data2["STATE_REVENUE"].fillna(us_data2.groupby("YEAR")["STATE_REVENUE"].transform("mean"))
us_data2["STATE_REVENUE"]=us_data2["STATE_REVENUE"].fillna(us_data2["STATE_REVENUE"].mean())

# %%
us_data2["LOCAL_REVENUE"]=us_data2["LOCAL_REVENUE"].fillna(us_data2.groupby("YEAR")["LOCAL_REVENUE"].transform("mean"))
us_data2["LOCAL_REVENUE"]=us_data2["LOCAL_REVENUE"].fillna(us_data2["LOCAL_REVENUE"].mean())

# %%
us_data2["TOTAL_EXPENDITURE"]=us_data2["TOTAL_EXPENDITURE"].fillna(us_data2.groupby("YEAR")["TOTAL_EXPENDITURE"].transform("mean"))
us_data2["TOTAL_EXPENDITURE"]=us_data2["TOTAL_EXPENDITURE"].fillna(us_data2["TOTAL_EXPENDITURE"].mean())

# %%
us_data2["INSTRUCTION_EXPENDITURE"]=us_data2["INSTRUCTION_EXPENDITURE"].fillna(us_data2.groupby("YEAR")["INSTRUCTION_EXPENDITURE"].transform("mean"))
us_data2["INSTRUCTION_EXPENDITURE"]=us_data2["INSTRUCTION_EXPENDITURE"].fillna(us_data2["INSTRUCTION_EXPENDITURE"].mean())

# %%
us_data2["SUPPORT_SERVICES_EXPENDITURE"]=us_data2["SUPPORT_SERVICES_EXPENDITURE"].fillna(us_data2.groupby("YEAR")["SUPPORT_SERVICES_EXPENDITURE"].transform("mean"))
us_data2["SUPPORT_SERVICES_EXPENDITURE"]=us_data2["SUPPORT_SERVICES_EXPENDITURE"].fillna(us_data2["SUPPORT_SERVICES_EXPENDITURE"].mean())

# %%
us_data2["OTHER_EXPENDITURE"]=us_data2["OTHER_EXPENDITURE"].fillna(us_data2.groupby("YEAR")["OTHER_EXPENDITURE"].transform("mean"))
us_data2["OTHER_EXPENDITURE"]=us_data2["OTHER_EXPENDITURE"].fillna(us_data2["OTHER_EXPENDITURE"].mean())

# %%
us_data2["CAPITAL_OUTLAY_EXPENDITURE"]=us_data2["CAPITAL_OUTLAY_EXPENDITURE"].fillna(us_data2.groupby("YEAR")["CAPITAL_OUTLAY_EXPENDITURE"].transform("mean"))
us_data2["CAPITAL_OUTLAY_EXPENDITURE"]=us_data2["CAPITAL_OUTLAY_EXPENDITURE"].fillna(us_data2["CAPITAL_OUTLAY_EXPENDITURE"].mean())

# %%
us_data2["GRADES_PK_G"]=us_data2["GRADES_PK_G"].fillna(us_data2.groupby("YEAR")["GRADES_PK_G"].transform("mean"))
us_data2["GRADES_PK_G"]=us_data2["GRADES_PK_G"].fillna(us_data2["GRADES_PK_G"].mean())

# %%
us_data2["GRADES_KG_G"]=us_data2["GRADES_KG_G"].fillna(us_data2.groupby("YEAR")["GRADES_KG_G"].transform("mean"))
us_data2["GRADES_KG_G"]=us_data2["GRADES_KG_G"].fillna(us_data2["GRADES_KG_G"].mean())

# %%
us_data2["GRADES_KG_G"]=us_data2["GRADES_KG_G"].fillna(us_data2.groupby("YEAR")["GRADES_KG_G"].transform("mean"))
us_data2["GRADES_KG_G"]=us_data2["GRADES_KG_G"].fillna(us_data2["GRADES_KG_G"].mean())

# %%
us_data2["GRADES_4_G"]=us_data2["GRADES_4_G"].fillna(us_data2.groupby("YEAR")["GRADES_4_G"].transform("mean"))
us_data2["GRADES_4_G"]=us_data2["GRADES_4_G"].fillna(us_data2["GRADES_4_G"].mean())

# %%
us_data2["GRADES_8_G"]=us_data2["GRADES_8_G"].fillna(us_data2.groupby("YEAR")["GRADES_8_G"].transform("mean"))
us_data2["GRADES_8_G"]=us_data2["GRADES_8_G"].fillna(us_data2["GRADES_8_G"].mean())

# %%
us_data2["GRADES_12_G"]=us_data2["GRADES_12_G"].fillna(us_data2.groupby("YEAR")["GRADES_12_G"].transform("mean"))
us_data2["GRADES_12_G"]=us_data2["GRADES_12_G"].fillna(us_data2["GRADES_12_G"].mean())

# %%
us_data2["GRADES_1_8_G"]=us_data2["GRADES_1_8_G"].fillna(us_data2.groupby("YEAR")["GRADES_1_8_G"].transform("mean"))
us_data2["GRADES_1_8_G"]=us_data2["GRADES_1_8_G"].fillna(us_data2["GRADES_1_8_G"].mean())

# %%
us_data2["GRADES_9_12_G"]=us_data2["GRADES_9_12_G"].fillna(us_data2.groupby("YEAR")["GRADES_9_12_G"].transform("mean"))
us_data2["GRADES_9_12_G"]=us_data2["GRADES_9_12_G"].fillna(us_data2["GRADES_9_12_G"].mean())

# %%
us_data2["GRADES_ALL_G"]=us_data2["GRADES_ALL_G"].fillna(us_data2.groupby("YEAR")["GRADES_ALL_G"].transform("mean"))
us_data2["GRADES_ALL_G"]=us_data2["GRADES_ALL_G"].fillna(us_data2["GRADES_ALL_G"].mean())

# %%
us_data2["AVG_MATH_4_SCORE"]=us_data2["AVG_MATH_4_SCORE"].fillna(us_data2.groupby("YEAR")["AVG_MATH_4_SCORE"].transform("mean"))
us_data2["AVG_MATH_4_SCORE"]=us_data2["AVG_MATH_4_SCORE"].fillna(us_data2["AVG_MATH_4_SCORE"].mean())

# %%
us_data2["AVG_MATH_8_SCORE"]=us_data2["AVG_MATH_8_SCORE"].fillna(us_data2.groupby("YEAR")["AVG_MATH_8_SCORE"].transform("mean"))
us_data2["AVG_MATH_8_SCORE"]=us_data2["AVG_MATH_8_SCORE"].fillna(us_data2["AVG_MATH_8_SCORE"].mean())

# %%
us_data2["AVG_READING_4_SCORE"]=us_data2["AVG_READING_4_SCORE"].fillna(us_data2.groupby("YEAR")["AVG_READING_4_SCORE"].transform("mean"))
us_data2["AVG_READING_4_SCORE"]=us_data2["AVG_READING_4_SCORE"].fillna(us_data2["AVG_READING_4_SCORE"].mean())

# %%
us_data2["AVG_READING_8_SCORE"]=us_data2["AVG_READING_8_SCORE"].fillna(us_data2.groupby("YEAR")["AVG_READING_8_SCORE"].transform("mean"))
us_data2["AVG_READING_8_SCORE"]=us_data2["AVG_READING_8_SCORE"].fillna(us_data2["AVG_READING_8_SCORE"].mean())

# %%
us_data2.isnull().sum()
# Out:
# PRIMARY_KEY                     0
# STATE                           0
# YEAR                            0
# ENROLL                          0
# TOTAL_REVENUE                   0
# FEDERAL_REVENUE                 0
# STATE_REVENUE                   0
# LOCAL_REVENUE                   0
# TOTAL_EXPENDITURE               0
# INSTRUCTION_EXPENDITURE         0
# SUPPORT_SERVICES_EXPENDITURE    0
# OTHER_EXPENDITURE               0
# CAPITAL_OUTLAY_EXPENDITURE      0
# GRADES_PK_G                     0
# GRADES_KG_G                     0
# GRADES_4_G                      0
# GRADES_8_G                      0
# GRADES_12_G                     0
# GRADES_1_8_G                    0
# GRADES_9_12_G                   0
# GRADES_ALL_G                    0
# AVG_MATH_4_SCORE                0
# AVG_MATH_8_SCORE                0
# AVG_READING_4_SCORE             0
# AVG_READING_8_SCORE             0
# dtype: int64

# %% [markdown]
# **4. This time, fill in the missing values by interpolating.**

# %%
for i in us_data3.columns[3:]:
    us_data3[i]=us_data3[i].fillna(us_data3[i].sort_values().interpolate(method ='linear', limit_direction ='forward'))

# %%
us_data3.isnull().sum()
# Out:
# PRIMARY_KEY                     0
# STATE                           0
# YEAR                            0
# ENROLL                          0
# TOTAL_REVENUE                   0
# FEDERAL_REVENUE                 0
# STATE_REVENUE                   0
# LOCAL_REVENUE                   0
# TOTAL_EXPENDITURE               0
# INSTRUCTION_EXPENDITURE         0
# SUPPORT_SERVICES_EXPENDITURE    0
# OTHER_EXPENDITURE               0
# CAPITAL_OUTLAY_EXPENDITURE      0
# GRADES_PK_G                     0
# GRADES_KG_G                     0
# GRADES_4_G                      0
# GRADES_8_G                      0
# GRADES_12_G                     0
# GRADES_1_8_G                    0
# GRADES_9_12_G                   0
# GRADES_ALL_G                    0
# AVG_MATH_4_SCORE                0
# AVG_MATH_8_SCORE                0
# AVG_READING_4_SCORE             0
# AVG_READING_8_SCORE             0
# dtype: int64

# %% [markdown]
# **5.Compare your answers on the second, third and fourth questions. Do you notice a meaningful difference?**

# %%
us_data1
# Out:
#              PRIMARY_KEY          STATE  YEAR        ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992  7.365843e+05     2678885.00
# 1            1992_ALASKA         ALASKA  1992  1.304296e+05     1049591.00
# 2           1992_ARIZONA        ARIZONA  1992  8.743221e+05     3258079.00
# 3          1992_ARKANSAS       ARKANSAS  1992  4.519019e+05     1711959.00
# 4        1992_CALIFORNIA     CALIFORNIA  1992  5.945343e+06    26260025.00
# ...                  ...            ...   ...           ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019  1.179632e+06    11237280.32
# 1711     2019_WASHINGTON     WASHINGTON  2019  1.010687e+06     9295918.12
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019  2.891283e+05     2664419.00
# 1713      2019_WISCONSIN      WISCONSIN  2019  8.671074e+05     8944846.84
# 1714        2019_WYOMING        WYOMING  2019  9.166442e+04     1173952.68
#
# ...

# %%
us_data2
# Out:
#              PRIMARY_KEY          STATE  YEAR         ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992  917561.547747   2.678885e+06
# 1            1992_ALASKA         ALASKA  1992  917561.547747   1.049591e+06
# 2           1992_ARIZONA        ARIZONA  1992  917561.547747   3.258079e+06
# 3          1992_ARKANSAS       ARKANSAS  1992  917561.547747   1.711959e+06
# 4        1992_CALIFORNIA     CALIFORNIA  1992  917561.547747   2.626002e+07
# ...                  ...            ...   ...            ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019  917561.547747   9.097897e+06
# 1711     2019_WASHINGTON     WASHINGTON  2019  917561.547747   9.097897e+06
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019  917561.547747   9.097897e+06
# 1713      2019_WISCONSIN      WISCONSIN  2019  917561.547747   9.097897e+06
# 1714        2019_WYOMING        WYOMING  2019  917561.547747   9.097897e+06
#
# ...

# %%
us_data3
# Out:
#              PRIMARY_KEY          STATE  YEAR     ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992  6307022.0      2678885.0
# 1            1992_ALASKA         ALASKA  1992  6307022.0      1049591.0
# 2           1992_ARIZONA        ARIZONA  1992  6307022.0      3258079.0
# 3          1992_ARKANSAS       ARKANSAS  1992  6307022.0      1711959.0
# 4        1992_CALIFORNIA     CALIFORNIA  1992  6307022.0     26260025.0
# ...                  ...            ...   ...        ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019  6307022.0     89217262.0
# 1711     2019_WASHINGTON     WASHINGTON  2019  6307022.0     89217262.0
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019  6307022.0     89217262.0
# 1713      2019_WISCONSIN      WISCONSIN  2019  6307022.0     89217262.0
# 1714        2019_WYOMING        WYOMING  2019  6307022.0     89217262.0
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# ...

# %% [markdown]
# the second method is better, because we filled it more specifically
