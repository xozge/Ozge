# %% [markdown]
# # MULTIVARIATE ANALYSIS

# %% [markdown]
# In this assignment, you will work on the Students Performance (dataset). You can reach the explanations of this data from Kaggle again.
#
# To complete this assignment, submit the Github link of the Jupyter notebook file containing solutions to the questions below. You can talk to your mentor on your head or ask Slack at office time.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# **(1) Does the performance in the exams vary according to gender, origin and education level of parents?**

# %%
st_per=pd.read_csv("StudentsPerformance.csv")
st_per
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
st_per.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
plt.figure(figsize=(20,20))
baslik_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
eksen_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }


plt.subplot(3,3,1)
plt.scatter(st_per["math score"], st_per["gender"])
plt.title("Math Score & Gender", fontdict=baslik_font)
plt.xlabel('Math Score', fontdict=eksen_font )
plt.ylabel('Gender', fontdict=eksen_font )


plt.subplot(3,3,2)
plt.scatter(st_per["math score"], st_per["race/ethnicity"])
plt.title("Math Score & Race/Ethnicity", fontdict=baslik_font)
plt.xlabel('Math Score', fontdict=eksen_font )
plt.ylabel('Race/Ethnicity', fontdict=eksen_font )


plt.subplot(3,3,3)
plt.scatter(st_per["math score"], st_per["parental level of education"])
plt.title("Math Score & Parental Level of Education", fontdict=baslik_font)
plt.xlabel('Math Score', fontdict=eksen_font )
plt.ylabel('Parental Level of Education', fontdict=eksen_font )





plt.subplot(3,3,4)
plt.scatter(st_per["reading score"], st_per["gender"])
plt.title("Reading Score & Gender", fontdict=baslik_font)
plt.xlabel('Reading Score', fontdict=eksen_font )
plt.ylabel('Gender', fontdict=eksen_font )


plt.subplot(3,3,5)
plt.scatter(st_per["reading score"], st_per["race/ethnicity"])
plt.title("Reading Score & Race/Ethnicity", fontdict=baslik_font)
plt.xlabel('Reading Score', fontdict=eksen_font )
plt.ylabel('Race/Ethnicity', fontdict=eksen_font )


plt.subplot(3,3,6)
plt.scatter(st_per["reading score"], st_per["parental level of education"])
plt.title("Reading Score & Parental Level of Education", fontdict=baslik_font)
plt.xlabel('Reading Score', fontdict=eksen_font )
plt.ylabel('Parental Level of Education', fontdict=eksen_font )






plt.subplot(3,3,7)
plt.scatter(st_per["writing score"], st_per["gender"])
plt.title("Writing Score & Gender", fontdict=baslik_font)
plt.xlabel('Writing Score', fontdict=eksen_font )
plt.ylabel('Gender', fontdict=eksen_font )


plt.subplot(3,3,8)
plt.scatter(st_per["writing score"], st_per["race/ethnicity"])
plt.title("Writing Score & Race/Ethnicity", fontdict=baslik_font)
plt.xlabel('Writing Score', fontdict=eksen_font )
plt.ylabel('Race/Ethnicity', fontdict=eksen_font )


plt.subplot(3,3,9)
plt.scatter(st_per["writing score"], st_per["parental level of education"])
plt.title("Writing Score & Parental Level of Education", fontdict=baslik_font)
plt.xlabel('Writing Score', fontdict=eksen_font )
plt.ylabel('Parental Level of Education', fontdict=eksen_font )


plt.show()

# %%
plt.figure(figsize=(20,20))
baslik_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
eksen_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }


plt.subplot(3,3,1)
sns.barplot(st_per["math score"], st_per["gender"])
plt.title("Math Score & Gender", fontdict=baslik_font)
plt.xlabel('Math Score', fontdict=eksen_font )
plt.ylabel('Gender', fontdict=eksen_font )


plt.subplot(3,3,2)
sns.barplot(st_per["math score"], st_per["race/ethnicity"])
plt.title("Math Score & Race/Ethnicity", fontdict=baslik_font)
plt.xlabel('Math Score', fontdict=eksen_font )
plt.ylabel('Race/Ethnicity', fontdict=eksen_font )


plt.subplot(3,3,3)
sns.barplot(st_per["math score"], st_per["parental level of education"])
plt.title("Math Score & Parental Level of Education", fontdict=baslik_font)
plt.xlabel('Math Score', fontdict=eksen_font )
plt.ylabel('Parental Level of Education', fontdict=eksen_font )





plt.subplot(3,3,4)
sns.barplot(st_per["reading score"], st_per["gender"])
plt.title("Reading Score & Gender", fontdict=baslik_font)
plt.xlabel('Reading Score', fontdict=eksen_font )
plt.ylabel('Gender', fontdict=eksen_font )


plt.subplot(3,3,5)
sns.barplot(st_per["reading score"], st_per["race/ethnicity"])
plt.title("Reading Score & Race/Ethnicity", fontdict=baslik_font)
plt.xlabel('Reading Score', fontdict=eksen_font )
plt.ylabel('Race/Ethnicity', fontdict=eksen_font )


plt.subplot(3,3,6)
sns.barplot(st_per["reading score"], st_per["parental level of education"])
plt.title("Reading Score & Parental Level of Education", fontdict=baslik_font)
plt.xlabel('Reading Score', fontdict=eksen_font )
plt.ylabel('Parental Level of Education', fontdict=eksen_font )






plt.subplot(3,3,7)
sns.barplot(st_per["writing score"], st_per["gender"])
plt.title("Writing Score & Gender", fontdict=baslik_font)
plt.xlabel('Writing Score', fontdict=eksen_font )
plt.ylabel('Gender', fontdict=eksen_font )


plt.subplot(3,3,8)
sns.barplot(st_per["writing score"], st_per["race/ethnicity"])
plt.title("Writing Score & Race/Ethnicity", fontdict=baslik_font)
plt.xlabel('Writing Score', fontdict=eksen_font )
plt.ylabel('Race/Ethnicity', fontdict=eksen_font )


plt.subplot(3,3,9)
sns.barplot(st_per["writing score"], st_per["parental level of education"])
plt.title("Writing Score & Parental Level of Education", fontdict=baslik_font)
plt.xlabel('Writing Score', fontdict=eksen_font )
plt.ylabel('Parental Level of Education', fontdict=eksen_font )


plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# **(2) Does lunch type have a relationship with exam performances? How can you explain this, if any?**

# %%
plt.figure(figsize=(10,20))
baslik_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
eksen_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }


plt.subplot(3,1,1)
sns.barplot(st_per["math score"], st_per["lunch"])
plt.title("Math Score & Lunch", fontdict=baslik_font)
plt.xlabel('Math Score', fontdict=eksen_font )
plt.ylabel('Lunch', fontdict=eksen_font )


plt.subplot(3,1,2)
sns.barplot(st_per["reading score"], st_per["lunch"])
plt.title("Reading Score & Lunch", fontdict=baslik_font)
plt.xlabel('Reading Score', fontdict=eksen_font )
plt.ylabel('Lunch', fontdict=eksen_font )


plt.subplot(3,1,3)
sns.barplot(st_per["writing score"], st_per["lunch"])
plt.title("Writing Score & Lunch", fontdict=baslik_font)
plt.xlabel('Writing Score', fontdict=eksen_font )
plt.ylabel('Lunch', fontdict=eksen_font )


plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# the effect of the standard lunch is more than free/reduced lunch for math, reading and writing score

# %% [markdown]
# **(3) Does the preparation courses have an impact on exam performance?**

# %%
plt.figure(figsize=(10,20))
baslik_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
eksen_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }


plt.subplot(3,1,1)
sns.barplot(st_per["math score"], st_per["test preparation course"])
plt.title("Math Score & Test Preparation Course", fontdict=baslik_font)
plt.xlabel('Math Score', fontdict=eksen_font )
plt.ylabel('Test Preparation Course', fontdict=eksen_font )


plt.subplot(3,1,2)
sns.barplot(st_per["reading score"], st_per["test preparation course"])
plt.title("Reading Score & Test Preparation Course", fontdict=baslik_font)
plt.xlabel('Reading Score', fontdict=eksen_font )
plt.ylabel('Test Preparation Course', fontdict=eksen_font )


plt.subplot(3,1,3)
sns.barplot(st_per["writing score"], st_per["test preparation course"])
plt.title("Writing Score & test preparation course", fontdict=baslik_font)
plt.xlabel('Writing Score', fontdict=eksen_font )
plt.ylabel('Test Preparation Course', fontdict=eksen_font )


plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# preparation courses increase success for math, reading and writing score

# %% [markdown]
# **(4) Which lessons are most correlated with each other?**

# %%
st_per_corr=st_per.corr()
st_per_corr
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %% [markdown]
# writing and reading have huge correlation.
#
# correlation score is 95%
