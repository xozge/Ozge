# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# In this assignment, you will continue to study the data of the US Education System (dataset). In this dataset, there is a lot of data on an annual basis. You can reach the explanations of this data from Kaggle again.
#
# To complete this assignment, submit the Github link of the Jupyter notebook file containing solutions to the questions below. You can talk to your mentor on your head or ask Slack at office time.
#
# First of all, apply the most appropriate one of the techniques for completing the missing values in your previous lesson. In order to answer the following questions, you must overcome the missing data.

# %% [markdown]
# **(1) Interpret the data by making univariate analysis and indicate the points you consider important.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
us_data=pd.read_csv("states_all.csv")
us_data
# Out:
#              PRIMARY_KEY          STATE  YEAR  ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992     NaN      2678885.0
# 1            1992_ALASKA         ALASKA  1992     NaN      1049591.0
# 2           1992_ARIZONA        ARIZONA  1992     NaN      3258079.0
# 3          1992_ARKANSAS       ARKANSAS  1992     NaN      1711959.0
# 4        1992_CALIFORNIA     CALIFORNIA  1992     NaN     26260025.0
# ...                  ...            ...   ...     ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019     NaN            NaN
# 1711     2019_WASHINGTON     WASHINGTON  2019     NaN            NaN
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019     NaN            NaN
# 1713      2019_WISCONSIN      WISCONSIN  2019     NaN            NaN
# 1714        2019_WYOMING        WYOMING  2019     NaN            NaN
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 0            304177.0      1659028.0       715680.0          2653798.0
# 1            106780.0       720711.0       222100.0           972488.0
# 2            297888.0      1369815.0      1590376.0          3401580.0
# 3            178571.0       958785.0       574603.0          1743022.0
# 4           2072470.0     16546514.0      7641041.0         27138832.0
# ...               ...            ...            ...                ...
# 1710              NaN            NaN            NaN                NaN
# 1711              NaN            NaN            NaN                NaN
# 1712              NaN            NaN            NaN                NaN
# 1713              NaN            NaN            NaN                NaN
# 1714              NaN            NaN            NaN                NaN
#
#       INSTRUCTION_EXPENDITURE  ...  GRADES_4_G  GRADES_8_G  GRADES_12_G  \
# 0                   1481703.0  ...     57948.0     58025.0      41167.0
# 1                    498362.0  ...      9748.0      8789.0       6714.0
# 2                   1435908.0  ...     55433.0     49081.0      37410.0
# 3                    964323.0  ...     34632.0     36011.0      27651.0
# 4                  14358922.0  ...    418418.0    363296.0     270675.0
# ...                       ...  ...         ...         ...          ...
# 1710                      NaN  ...         NaN         NaN          NaN
# 1711                      NaN  ...         NaN         NaN          NaN
# 1712                      NaN  ...         NaN         NaN          NaN
# 1713                      NaN  ...         NaN         NaN          NaN
# 1714                      NaN  ...         NaN         NaN          NaN
#
#       GRADES_1_8_G  GRADES_9_12_G  GRADES_ALL_G  AVG_MATH_4_SCORE  \
# 0              NaN            NaN      731634.0             208.0
# 1              NaN            NaN      122487.0               NaN
# 2              NaN            NaN      673477.0             215.0
# 3              NaN            NaN      441490.0             210.0
# 4              NaN            NaN     5254844.0             208.0
# ...            ...            ...           ...               ...
# 1710           NaN            NaN           NaN             247.0
# 1711           NaN            NaN           NaN             240.0
# 1712           NaN            NaN           NaN             231.0
# 1713           NaN            NaN           NaN             242.0
# 1714           NaN            NaN           NaN             246.0
#
#       AVG_MATH_8_SCORE  AVG_READING_4_SCORE  AVG_READING_8_SCORE
# 0                252.0                207.0                  NaN
# 1                  NaN                  NaN                  NaN
# 2                265.0                209.0                  NaN
# 3                256.0                211.0                  NaN
# 4                261.0                202.0                  NaN
# ...                ...                  ...                  ...
# 1710             287.0                224.0                262.0
# 1711             286.0                220.0                266.0
# 1712             272.0                213.0                256.0
# 1713             289.0                220.0                267.0
# 1714             286.0                227.0                265.0
#
# [1715 rows x 25 columns]

# %%
us_data2=us_data.copy()

# %%
us_data2["ENROLL"]=us_data2["ENROLL"].fillna(us_data2.groupby("YEAR")["ENROLL"].transform("mean"))
us_data2["ENROLL"]=us_data2["ENROLL"].fillna(us_data2["ENROLL"].mean())

# %%
us_data2["TOTAL_REVENUE"]=us_data2["TOTAL_REVENUE"].fillna(us_data2.groupby("YEAR")["TOTAL_REVENUE"].transform("mean"))
us_data2["TOTAL_REVENUE"]=us_data2["TOTAL_REVENUE"].fillna(us_data2["TOTAL_REVENUE"].mean())

# %%
us_data2["FEDERAL_REVENUE"]=us_data2["FEDERAL_REVENUE"].fillna(us_data2.groupby("YEAR")["FEDERAL_REVENUE"].transform("mean"))
us_data2["FEDERAL_REVENUE"]=us_data2["FEDERAL_REVENUE"].fillna(us_data2["FEDERAL_REVENUE"].mean())

# %%
us_data2["FEDERAL_REVENUE"]=us_data2["FEDERAL_REVENUE"].fillna(us_data2.groupby("YEAR")["FEDERAL_REVENUE"].transform("mean"))
us_data2["FEDERAL_REVENUE"]=us_data2["FEDERAL_REVENUE"].fillna(us_data2["FEDERAL_REVENUE"].mean())

# %%
us_data2["STATE_REVENUE"]=us_data2["STATE_REVENUE"].fillna(us_data2.groupby("YEAR")["STATE_REVENUE"].transform("mean"))
us_data2["STATE_REVENUE"]=us_data2["STATE_REVENUE"].fillna(us_data2["STATE_REVENUE"].mean())

# %%
us_data2["LOCAL_REVENUE"]=us_data2["LOCAL_REVENUE"].fillna(us_data2.groupby("YEAR")["LOCAL_REVENUE"].transform("mean"))
us_data2["LOCAL_REVENUE"]=us_data2["LOCAL_REVENUE"].fillna(us_data2["LOCAL_REVENUE"].mean())

# %%
us_data2["TOTAL_EXPENDITURE"]=us_data2["TOTAL_EXPENDITURE"].fillna(us_data2.groupby("YEAR")["TOTAL_EXPENDITURE"].transform("mean"))
us_data2["TOTAL_EXPENDITURE"]=us_data2["TOTAL_EXPENDITURE"].fillna(us_data2["TOTAL_EXPENDITURE"].mean())

# %%
us_data2["INSTRUCTION_EXPENDITURE"]=us_data2["INSTRUCTION_EXPENDITURE"].fillna(us_data2.groupby("YEAR")["INSTRUCTION_EXPENDITURE"].transform("mean"))
us_data2["INSTRUCTION_EXPENDITURE"]=us_data2["INSTRUCTION_EXPENDITURE"].fillna(us_data2["INSTRUCTION_EXPENDITURE"].mean())

# %%
us_data2["SUPPORT_SERVICES_EXPENDITURE"]=us_data2["SUPPORT_SERVICES_EXPENDITURE"].fillna(us_data2.groupby("YEAR")["SUPPORT_SERVICES_EXPENDITURE"].transform("mean"))
us_data2["SUPPORT_SERVICES_EXPENDITURE"]=us_data2["SUPPORT_SERVICES_EXPENDITURE"].fillna(us_data2["SUPPORT_SERVICES_EXPENDITURE"].mean())

# %%
us_data2["OTHER_EXPENDITURE"]=us_data2["OTHER_EXPENDITURE"].fillna(us_data2.groupby("YEAR")["OTHER_EXPENDITURE"].transform("mean"))
us_data2["OTHER_EXPENDITURE"]=us_data2["OTHER_EXPENDITURE"].fillna(us_data2["OTHER_EXPENDITURE"].mean())

# %%
us_data2["CAPITAL_OUTLAY_EXPENDITURE"]=us_data2["CAPITAL_OUTLAY_EXPENDITURE"].fillna(us_data2.groupby("YEAR")["CAPITAL_OUTLAY_EXPENDITURE"].transform("mean"))
us_data2["CAPITAL_OUTLAY_EXPENDITURE"]=us_data2["CAPITAL_OUTLAY_EXPENDITURE"].fillna(us_data2["CAPITAL_OUTLAY_EXPENDITURE"].mean())

# %%
us_data2["GRADES_PK_G"]=us_data2["GRADES_PK_G"].fillna(us_data2.groupby("YEAR")["GRADES_PK_G"].transform("mean"))
us_data2["GRADES_PK_G"]=us_data2["GRADES_PK_G"].fillna(us_data2["GRADES_PK_G"].mean())

# %%
us_data2["GRADES_KG_G"]=us_data2["GRADES_KG_G"].fillna(us_data2.groupby("YEAR")["GRADES_KG_G"].transform("mean"))
us_data2["GRADES_KG_G"]=us_data2["GRADES_KG_G"].fillna(us_data2["GRADES_KG_G"].mean())

# %%
us_data2["GRADES_4_G"]=us_data2["GRADES_4_G"].fillna(us_data2.groupby("YEAR")["GRADES_4_G"].transform("mean"))
us_data2["GRADES_4_G"]=us_data2["GRADES_4_G"].fillna(us_data2["GRADES_4_G"].mean())

# %%
us_data2["GRADES_8_G"]=us_data2["GRADES_8_G"].fillna(us_data2.groupby("YEAR")["GRADES_8_G"].transform("mean"))
us_data2["GRADES_8_G"]=us_data2["GRADES_8_G"].fillna(us_data2["GRADES_8_G"].mean())

# %%
us_data2["GRADES_12_G"]=us_data2["GRADES_12_G"].fillna(us_data2.groupby("YEAR")["GRADES_12_G"].transform("mean"))
us_data2["GRADES_12_G"]=us_data2["GRADES_12_G"].fillna(us_data2["GRADES_12_G"].mean())

# %%
us_data2["GRADES_1_8_G"]=us_data2["GRADES_1_8_G"].fillna(us_data2.groupby("YEAR")["GRADES_1_8_G"].transform("mean"))
us_data2["GRADES_1_8_G"]=us_data2["GRADES_1_8_G"].fillna(us_data2["GRADES_1_8_G"].mean())

# %%
us_data2["GRADES_9_12_G"]=us_data2["GRADES_9_12_G"].fillna(us_data2.groupby("YEAR")["GRADES_9_12_G"].transform("mean"))
us_data2["GRADES_9_12_G"]=us_data2["GRADES_9_12_G"].fillna(us_data2["GRADES_9_12_G"].mean())

# %%
us_data2["GRADES_ALL_G"]=us_data2["GRADES_ALL_G"].fillna(us_data2.groupby("YEAR")["GRADES_ALL_G"].transform("mean"))
us_data2["GRADES_ALL_G"]=us_data2["GRADES_ALL_G"].fillna(us_data2["GRADES_ALL_G"].mean())

# %%
us_data2["AVG_MATH_4_SCORE"]=us_data2["AVG_MATH_4_SCORE"].fillna(us_data2.groupby("YEAR")["AVG_MATH_4_SCORE"].transform("mean"))
us_data2["AVG_MATH_4_SCORE"]=us_data2["AVG_MATH_4_SCORE"].fillna(us_data2["AVG_MATH_4_SCORE"].mean())

# %%
us_data2["AVG_MATH_8_SCORE"]=us_data2["AVG_MATH_8_SCORE"].fillna(us_data2.groupby("YEAR")["AVG_MATH_8_SCORE"].transform("mean"))
us_data2["AVG_MATH_8_SCORE"]=us_data2["AVG_MATH_8_SCORE"].fillna(us_data2["AVG_MATH_8_SCORE"].mean())

# %%
us_data2["AVG_READING_4_SCORE"]=us_data2["AVG_READING_4_SCORE"].fillna(us_data2.groupby("YEAR")["AVG_READING_4_SCORE"].transform("mean"))
us_data2["AVG_READING_4_SCORE"]=us_data2["AVG_READING_4_SCORE"].fillna(us_data2["AVG_READING_4_SCORE"].mean())

# %%
us_data2["AVG_READING_8_SCORE"]=us_data2["AVG_READING_8_SCORE"].fillna(us_data2.groupby("YEAR")["AVG_READING_8_SCORE"].transform("mean"))
us_data2["AVG_READING_8_SCORE"]=us_data2["AVG_READING_8_SCORE"].fillna(us_data2["AVG_READING_8_SCORE"].mean())

# %%
us_data2
# Out:
#              PRIMARY_KEY          STATE  YEAR         ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992  917561.547747   2.678885e+06
# 1            1992_ALASKA         ALASKA  1992  917561.547747   1.049591e+06
# 2           1992_ARIZONA        ARIZONA  1992  917561.547747   3.258079e+06
# 3          1992_ARKANSAS       ARKANSAS  1992  917561.547747   1.711959e+06
# 4        1992_CALIFORNIA     CALIFORNIA  1992  917561.547747   2.626002e+07
# ...                  ...            ...   ...            ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019  917561.547747   9.097897e+06
# 1711     2019_WASHINGTON     WASHINGTON  2019  917561.547747   9.097897e+06
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019  917561.547747   9.097897e+06
# 1713      2019_WISCONSIN      WISCONSIN  2019  917561.547747   9.097897e+06
# 1714        2019_WYOMING        WYOMING  2019  917561.547747   9.097897e+06
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 0        3.041770e+05   1.659028e+06   7.156800e+05       2.653798e+06
# 1        1.067800e+05   7.207110e+05   2.221000e+05       9.724880e+05
# 2        2.978880e+05   1.369815e+06   1.590376e+06       3.401580e+06
# 3        1.785710e+05   9.587850e+05   5.746030e+05       1.743022e+06
# 4        2.072470e+06   1.654651e+07   7.641041e+06       2.713883e+07
# ...               ...            ...            ...                ...
# 1710     7.674020e+05   4.221979e+06   4.108516e+06       9.202368e+06
# 1711     7.674020e+05   4.221979e+06   4.108516e+06       9.202368e+06
# 1712     7.674020e+05   4.221979e+06   4.108516e+06       9.202368e+06
# 1713     7.674020e+05   4.221979e+06   4.108516e+06       9.202368e+06
# 1714     7.674020e+05   4.221979e+06   4.108516e+06       9.202368e+06
#
#       INSTRUCTION_EXPENDITURE  ...     GRADES_4_G     GRADES_8_G  \
# 0                1.481703e+06  ...   57948.000000   58025.000000
# 1                4.983620e+05  ...    9748.000000    8789.000000
# 2                1.435908e+06  ...   55433.000000   49081.000000
# 3                9.643230e+05  ...   34632.000000   36011.000000
# 4                1.435892e+07  ...  418418.000000  363296.000000
# ...                       ...  ...            ...            ...
# 1710             4.765951e+06  ...   69192.051379   68138.013603
# 1711             4.765951e+06  ...   69192.051379   68138.013603
# 1712             4.765951e+06  ...   69192.051379   68138.013603
# 1713             4.765951e+06  ...   69192.051379   68138.013603
# 1714             4.765951e+06  ...   69192.051379   68138.013603
#
#         GRADES_12_G  GRADES_1_8_G  GRADES_9_12_G  GRADES_ALL_G  \
VG_MATH_8_SCORE  AVG_READING_4_SCORE  AVG_READING_8_SCORE
# count       1715.000000          1715.000000          1715.000000
# mean         277.061986           218.166988           262.953340
# std            6.483988             4.868461             3.873393
# min          231.000000           179.000000           236.000000
# 25%          277.061986           218.166988           262.953340
# 50%          277.061986           218.166988           262.953340
# 75%          277.061986           218.166988           262.953340
# max          301.000000           237.000000           280.000000
#
# [8 rows x 23 columns]

# %%
us_data2.describe(include=['O']) # for object variables
# Out:
#              PRIMARY_KEY    STATE
# count               1715     1715
# unique              1715       53
# top     1990_CONNECTICUT  MONTANA
# freq                   1       33

# %%
from scipy.stats.mstats import winsorize
us_data2["winsorize_TOTAL_REVENUE"] = winsorize(us_data2["TOTAL_REVENUE"], (0.1, 0.05))
us_data2["winsorize_TOTAL_EXPENDITURE"] = winsorize(us_data2["TOTAL_EXPENDITURE"], (0.1, 0.05))

# %%
plt.figure(figsize=(18,15))
baslik_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
eksen_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }

val = ['TOTAL_REVENUE', 'TOTAL_EXPENDITURE']
winsorize_val = ['winsorize_TOTAL_REVENUE', 'winsorize_TOTAL_EXPENDITURE']

for i in range(2):
    plt.subplot(3, 2, i+1)
    plt.hist(us_data2[val[i]], color="red")
    plt.title(val[i], fontdict=baslik_font)
    
for i in range(2):
    plt.subplot(3, 2, i+3)
    plt.hist(us_data2[winsorize_val[i]], color="darkblue")
    plt.title(winsorize_val[i], fontdict=baslik_font)
    
for i in range(2):
    plt.subplot(3, 2, i+5)
    plt.hist(np.log(us_data2[val[i]]), color="purple")
    plt.title(val[i] + '(log)', fontdict=baslik_font)

# %% [markdown]
# log distribution is closer to normal distribution

# %% [markdown]
# **(2) Consider a state (eg California) and plot the yearly change of total revenues and total spending. Do these two variables change by years? Do you have years of summit and bottom?**

# %%
st=us_data2[(us_data2["STATE"]=="CALIFORNIA") & (us_data2["YEAR"]) & (us_data2["TOTAL_REVENUE"]) & (us_data2["TOTAL_EXPENDITURE"])]

# %%
st.describe()
# Out:
#               YEAR        ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# count    17.000000  1.700000e+01   1.700000e+01     1.700000e+01
# mean   2003.000000  4.481844e+06   4.234563e+07     4.388492e+06
# std      10.099505  2.395743e+06   2.678749e+07     3.318726e+06
# min    1987.000000  9.175615e+05   9.097897e+06     7.674020e+05
# 25%    1995.000000  9.175615e+05   9.097897e+06     7.674020e+05
# 50%    2003.000000  5.839207e+06   4.139344e+07     3.599923e+06
# 75%    2011.000000  6.226523e+06   6.886852e+07     7.200298e+06
# max    2019.000000  6.307022e+06   7.824804e+07     9.990221e+06
#
#        STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# count   1.700000e+01   1.700000e+01       1.700000e+01
# mean    2.326756e+07   1.468958e+07       4.252224e+07
# std     1.497804e+07   8.748339e+06       2.703415e+07
# min     4.221979e+06   4.108516e+06       9.202368e+06
# 25%     4.221979e+06   4.108516e+06       9.202368e+06
# 50%     2.369510e+07   1.409842e+07       4.083464e+07
# 75%     3.514121e+07   2.298300e+07       6.972712e+07
# max     4.236047e+07   2.833121e+07       7.836596e+07
#
#        INSTRUCTION_EXPENDITURE  SUPPORT_SERVICES_EXPENDITURE  \
# count             1.700000e+01                  1.200000e+01
# mean              2.114572e+07                  1.625127e+07
# std               1.289499e+07                  5.376707e+06
# min               4.765951e+06                  8.603751e+06
# 25%               4.765951e+06                  1.116503e+07
# 50%               2.111054e+07                  1.753836e+07
# 75%               3.419488e+07                  2.061043e+07
# max               3.895195e+07                  2.350185e+07
#
#        OTHER_EXPENDITURE  ...    GRADES_12_G  GRADES_1_8_G  GRADES_9_12_G  \
# count       1.700000e+01  ...      17.000000  1.000000e+01   1.700000e+01
# mean        2.136130e+06  ...  362595.389823  3.775729e+06   1.313139e+06
# std         1.311313e+06  ...  122420.559390  9.429069e+04   7.932300e+05
# min         4.299401e+05  ...   58440.626991  3.591033e+06   2.820837e+05
# 25%         4.299401e+05  ...  277271.000000  3.736925e+06   2.820837e+05
# 50%         2.181053e+06  ...  365907.000000  3.759766e+06   1.745295e+06
# 75%         3.461759e+06  ...  478503.000000  3.836762e+06   1.952314e+06
# max         3.759373e+06  ...  498403.000000  3.929869e+06   2.011865e+06
#
#        GRADES_ALL_G  AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  AVG_READING_4_SCORE  \
# count  1.700000e+01         17.000000         17.000000            17.000000
# mean   5.577946e+06        232.445798        274.676229           214.431524
# std    1.347908e+06          1.905421          3.466196             4.371389
# min    9.142853e+05        227.000000        267.000000           206.000000
# 25%    5.327231e+06        232.000000        273.000000           211.000000
# 50%    6.226737e+06        233.197320        277.000000           216.000000
# 75%    6.304266e+06        233.197320        277.061986           218.166988
# max    6.437202e+06        235.000000        277.061986           218.166988
#
#        AVG_READING_8_SCORE  winsorize_TOTAL_REVENUE  \
# count            17.000000             1.700000e+01
# mean            259.213337             2.150612e+07
# std               5.063703             8.255978e+06
# min             250.000000             9.097897e+06
# 25%             255.000000             9.097897e+06
# 50%             262.953340             2.667622e+07
# 75%             262.953340             2.667622e+07
# max             263.000000             2.667622e+07
#
#        winsorize_TOTAL_EXPENDITURE
# count                 1.700000e+01
# mean                  2.196097e+07
# std                   8.489103e+06
# min                   9.202368e+06
# 25%                   9.202368e+06
# 50%                   2.727705e+07
# 75%                   2.727705e+07
# max                   2.727705e+07
#
# [8 rows x 25 columns]

# %%
st1=us_data2[(us_data2["STATE"]=="CALIFORNIA") & (us_data2["TOTAL_REVENUE"]) & (us_data2["TOTAL_EXPENDITURE"])]
st1
# Out:
#           PRIMARY_KEY       STATE  YEAR        ENROLL  TOTAL_REVENUE  \
# 4     1992_CALIFORNIA  CALIFORNIA  1992  9.175615e+05   2.626002e+07
# 55    1993_CALIFORNIA  CALIFORNIA  1993  5.129788e+06   2.804334e+07
# 106   1994_CALIFORNIA  CALIFORNIA  1994  4.120498e+06   2.344084e+07
# 157   1995_CALIFORNIA  CALIFORNIA  1995  5.299405e+06   2.951221e+07
# 208   1996_CALIFORNIA  CALIFORNIA  1996  5.460484e+06   3.128298e+07
# 259   1997_CALIFORNIA  CALIFORNIA  1997  5.595836e+06   3.561493e+07
# 310   1998_CALIFORNIA  CALIFORNIA  1998  5.727224e+06   3.918302e+07
# 361   1999_CALIFORNIA  CALIFORNIA  1999  5.839207e+06   4.139344e+07
# 412   2000_CALIFORNIA  CALIFORNIA  2000  5.941946e+06   4.662821e+07
# 718      7.421482e+06   3.743965e+07   2.144173e+07       6.872243e+07
# 769      7.200298e+06   4.233364e+07   2.298300e+07       7.322542e+07
# 820      7.227456e+06   4.318764e+07   2.421184e+07       7.661886e+07
# 871      9.745250e+06   4.008424e+07   2.412940e+07       7.476609e+07
# 922      9.715980e+06   3.417391e+07   2.346683e+07       7.122711e+07
# 973      9.990221e+06   3.775271e+07   2.321040e+07       6.984770e+07
# 1024     8.793325e+06   3.641327e+07   2.380979e+07       7.019188e+07
# 1075     7.836263e+06   3.514121e+07   2.589104e+07       6.972712e+07
# 1126     7.415061e+06   3.841055e+07   2.656351e+07       7.250681e+07
# 1177     7.556365e+06   4.236047e+07   2.833121e+07       7.836596e+07
# 1228     7.709079e+06   5.090457e+07   3.060362e+07       8.532013e+07
# 1303     7.674020e+05   4.221979e+06   4.108516e+06       9.202368e+06
# 1304     7.674020e+05   4.221979e+06   4.108516e+06       9.202368e+06
# 1305     7.674020e+05   4.221979e+06   4.108516e+06       9.202368e+06
# 1306     7.674020e+05   4.221979e+06   4.108516e+06       9.202368e+06
# 1307     7.674020e+05   4.221979e+06   4.108516e+06       9.202368e+06
# 1308     7.674020e+05   4.221979e+06   4.108516e+06       9.202368e+06
# 1309     7.674020e+05   4.221979e+06   4.108516e+06       9.202368e+06
# 1666     7.674020e+05   4.221979e+06   4.108516e+06       9.202368e+06
#
#       INSTRUCTION_EXPENDITURE  ...    GRADES_12_G  GRADES_1_8_G  \
# 4                1.435892e+07  ...  270675.000000           NaN
# 55               1.528115e+07  ...  277271.000000           NaN
# 106              1.244386e+07  ...  285132.000000           NaN
# 157              1.614642e+07  ...  287428.000000           NaN
# 208              1.688073e+07  ...  298669.000000           NaN
# 259              1.816044e+07  ...  317595.000000     3591033.0
# 310              2.008391e+07  ...  334852.000000     3666271.0
# 361              2.111054e+07  ...  347914.000000     3734997.0
# 412              2.351439e+07  ...  357789.000000     3804640.0
# 463              2.664181e+07  ...  365907.000000     3871843.0
# 514              2.859316e+07  ...  385181.000000     3917027.0
# 565              2.956156e+07  ...  395194.000000     3929869.0
# 616              2.962497e+07  ...  409576.000000     3897579.0
# 667              3.107045e+07  ...  423241.000000     3848455.0
# 718              3.238767e+07  ...  443253.000000     3830950.0
# 769              3.468501e+07  ...  468281.000000     3801685.0
# 820              3.654235e+07  ...  476156.000000     3770281.0
# 871              3.561796e+07  ...  478503.000000     3717166.0
# 922              3.465728e+07  ...  492545.000000     3749960.0
# 973              3.422525e+07  ...  494144.000000     3742708.0
# 1024             3.421305e+07  ...  496754.000000     3763810.0
# 1075             3.419488e+07  ...  498403.000000     3771067.0
# 1126             3.553942e+07  ...  496901.000000     3767745.0
# 1177             3.895195e+07  ...  492835.000000     3748465.0
# 1228             4.258727e+07  ...  484169.000000     3747077.0
# 1303             4.765951e+06  ...  251281.000000           NaN
# 1304             4.765951e+06  ...  266028.000000           NaN
# 1305             4.765951e+06  ...  257450.000000           NaN
# 1306             4.765951e+06  ...  243023.000000           NaN
# 1307             4.765951e+06  ...  244142.000000           NaN
# 1308             4.765951e+06  ...  260693.000000           NaN
# 1309             4.765951e+06  ...  489221.000000           NaN
# 1666             4.765951e+06  ...   58440.626991           NaN
#
#       GRADES_9_12_G  GRADES_ALL_G  AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  \
#
# 1308           218.166988            262.95334             9.097897e+06
# 1309           215.000000            263.00000             9.097897e+06
# 1666           216.000000            259.00000             9.097897e+06
#
#       winsorize_TOTAL_EXPENDITURE
# 4                    2.713883e+07
# 55                   2.727705e+07
# 106                  2.301269e+07
# 157                  2.727705e+07
# 208                  2.727705e+07
# 259                  2.727705e+07
# 310                  2.727705e+07
# 361                  2.727705e+07
# 412                  2.727705e+07
# 463                  2.727705e+07
# 514                  2.727705e+07
# 565                  2.727705e+07
# 616                  2.727705e+07
# 667                  2.727705e+07
# 718                  2.727705e+07
# 769                  2.727705e+07
# 820                  2.727705e+07
# 871                  2.727705e+07
# 922                  2.727705e+07
# 973                  2.727705e+07
# 1024                 2.727705e+07
# 1075                 2.727705e+07
# 1126                 2.727705e+07
# 1177                 2.727705e+07
# 1228                 2.727705e+07
# 1303                 9.202368e+06
# 1304                 9.202368e+06
# 1305                 9.202368e+06
# 1306                 9.202368e+06
# 1307                 9.202368e+06
# 1308                 9.202368e+06
# 1309                 9.202368e+06
# 1666                 9.202368e+06
#
# [33 rows x 27 columns]

# %%
st1.describe()
# Out:
#               YEAR        ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# count    33.000000  3.300000e+01   3.300000e+01     3.300000e+01
# mean   2002.030303  4.574130e+06   4.447767e+07     4.571329e+06
# std       9.722670  2.315621e+06   2.618290e+07     3.165667e+06
# min    1986.000000  9.175615e+05   9.097897e+06     7.674020e+05
# 25%    1994.000000  9.175615e+05   2.344084e+07     2.072470e+06
# 50%    2002.000000  5.941946e+06   4.662821e+07     4.024940e+06
# 75%    2010.000000  6.224685e+06   6.886852e+07     7.415061e+06
# max    2019.000000  6.307022e+06   8.921726e+07     9.990221e+06
#
#        STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# count   3.300000e+01   3.300000e+01       3.300000e+01
# mean    2.448509e+07   1.542125e+07       4.484289e+07
# std     1.462230e+07   8.667752e+06       2.644760e+07
# min     4.221979e+06   4.108516e+06       9.202368e+06
# 25%     1.317555e+07   7.641041e+06       2.301269e+07
# 50%     2.687792e+07   1.572535e+07       4.582975e+07
# 75%     3.641327e+07   2.321040e+07       6.984770e+07
# max     5.090457e+07   3.060362e+07       8.532013e+07
#
#        INSTRUCTION_EXPENDITURE  SUPPORT_SERVICES_EXPENDITURE  \
# count             3.300000e+01                  2.500000e+01
# mean              2.227885e+07                  1.623720e+07
# std               1.260054e+07                  5.657804e+06
# min               4.765951e+06                  6.754346e+06
# 25%               1.244386e+07                  1.093906e+07
# 50%               2.351439e+07                  1.733888e+07
# 75%               3.421305e+07                  2.065519e+07
# max               4.258727e+07                  2.605802e+07
#
#        OTHER_EXPENDITURE  ...    GRADES_12_G  GRADES_1_8_G  GRADES_9_12_G  \
# count       3.300000e+01  ...      33.000000  2.000000e+01   3.300000e+01
# mean        2.231792e+06  ...  368140.806879  3.783631e+06   1.300877e+06
# std         1.295872e+06  ...  109744.501534  8.308744e+04   7.894197e+05
# min         4.299401e+05  ...   58440.626991  3.591033e+06   2.820837e+05
# 25%         4.299401e+05  ...  277271.000000  3.745985e+06   2.820837e+05
# 50%         2.362407e+06  ...  365907.000000  3.769013e+06   1.745295e+06
# 75%         3.467540e+06  ...  478503.000000  3.835326e+06   1.952314e+06
# max         3.995951e+06  ...  498403.000000  3.929869e+06   2.013687e+06
#
#        GRADES_ALL_G  AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  AVG_READING_4_SCORE  \
# count  3.300000e+01         33.000000         33.000000            33.000000
# mean   5.694602e+06        230.543830        273.976961           214.096145
# std    1.070167e+06          6.544791          5.638865             5.972874
# min    9.142853e+05        208.000000        256.000000           197.000000
# 25%    5.327231e+06        232.000000        273.000000           211.000000
# 50%    6.226737e+06        233.197320        277.061986           218.166988
# 75%    6.312161e+06        233.197320        277.061986           218.166988
# max    6.441557e+06        235.000000        277.061986           218.166988
#
#        AVG_READING_8_SCORE  winsorize_TOTAL_REVENUE  \
# count            33.000000             3.300000e+01
# mean            260.123236             2.230415e+07
# std               4.639986             7.607205e+06
# min             250.000000             9.097897e+06
# 25%             259.000000             2.344084e+07
# 50%             262.953340             2.667622e+07
# 75%             262.953340             2.667622e+07
# max             263.000000             2.667622e+07
#
#        winsorize_TOTAL_EXPENDITURE
# count                 3.300000e+01
# mean                  2.276190e+07
# std                   7.824239e+06
# min                   9.202368e+06
# 25%                   2.301269e+07
# 50%                   2.727705e+07
# 75%                   2.727705e+07
# max                   2.727705e+07
#
# [8 rows x 25 columns]

# %%
plt.figure(figsize=(10, 6))
plt.suptitle("CALIFORNIA")
plt.scatter(st1["YEAR"],st1["TOTAL_REVENUE"], color = "yellow")
plt.scatter(st1["YEAR"],st1["TOTAL_EXPENDITURE"], color = "green")
plt.xticks(rotation = 45, fontsize = 9)
plt.legend(["TOTAL_REVENUE","TOTAL_EXPENDITURE"])
plt.show()

# %% [markdown]
# Two variables change by years. There are summit and bottom points for total revenue and total expenditure

# %% [markdown]
# **(3)In which course are students more successful in your chosen state? Mathematics or reading?**

# %% [markdown]
# mean of math scores are bigger than mean of reading scores

# %% [markdown]
# **(4) What is the distribution of mathematics and reading grades?**

# %%
st2=us_data2[(us_data2["STATE"]=="CALIFORNIA") & (us_data2["AVG_MATH_4_SCORE"]) & (us_data2["AVG_MATH_8_SCORE"]) & (us_data2["AVG_READING_4_SCORE"]) & (us_data2["AVG_READING_8_SCORE"])]

# %%
plt.figure(figsize=(18,15))
val2 = ['AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE', 'AVG_READING_4_SCORE', 'AVG_READING_8_SCORE']
for i in range(4):
    plt.subplot(2, 2, i+1)
    plt.hist(st2[val2[i]], color="darkblue")
    plt.title(val2[i], fontdict=baslik_font)

# %% [markdown]
# there is no normal distribution

# %% [markdown]
# **(5) You may have noticed that there are many missing values in the mathematics and reading notes. Complete the missing values with mean, median, and interpolation. Compare the impact of these techniques on the distribution of grades.**

# %%
us_data3=us_data.copy()

# %%
us_data4=us_data.copy()

# %%
us_data3["AVG_MATH_4_SCORE"]=us_data3["AVG_MATH_4_SCORE"].fillna(us_data3["AVG_MATH_4_SCORE"].median())

# %%
us_data3["AVG_MATH_8_SCORE"]=us_data3["AVG_MATH_8_SCORE"].fillna(us_data3["AVG_MATH_8_SCORE"].median())

# %%
us_data3["AVG_READING_4_SCORE"]=us_data3["AVG_READING_4_SCORE"].fillna(us_data3["AVG_READING_4_SCORE"].median())

# %%
us_data3["AVG_READING_8_SCORE"]=us_data3["AVG_READING_8_SCORE"].fillna(us_data3["AVG_READING_8_SCORE"].median())

# %%
for i in us_data4.columns[21:]:
    us_data4[i]=us_data4[i].fillna(us_data4[i].sort_values().interpolate(method ='linear', limit_direction ='forward'))

# %%
us_data2.describe().AVG_MATH_4_SCORE   # MEAN
# Out:
# count    1715.00000
# mean      233.19732
# std         6.95080
# min       192.00000
# 25%       233.19732
# 50%       233.19732
# 75%       233.19732
# max       253.00000
# Name: AVG_MATH_4_SCORE, dtype: float64

# %%
us_data3.describe().AVG_MATH_4_SCORE    # MEDIAN
# Out:
# count    1715.000000
# mean      237.448980
# std         5.384205
# min       192.000000
# 25%       238.000000
# 50%       238.000000
# 75%       238.000000
# max       253.000000
# Name: AVG_MATH_4_SCORE, dtype: float64

# %%
us_data4.describe().AVG_MATH_4_SCORE    # INTERPOLATION
# Out:
# count    1715.000000
# mean      247.507289
# std         9.477070
# min       192.000000
# 25%       243.000000
# 50%       253.000000
# 75%       253.000000
# max       253.000000
# Name: AVG_MATH_4_SCORE, dtype: float64

# %%
us_data2.describe().AVG_MATH_8_SCORE    # MEAN
# Out:
# count    1715.000000
# mean      277.061986
# std         6.483988
# min       231.000000
# 25%       277.061986
# 50%       277.061986
# 75%       277.061986
# max       301.000000
# Name: AVG_MATH_8_SCORE, dtype: float64

# %%
us_data3.describe().AVG_MATH_8_SCORE   # MEDIAN
# Out:
# count    1715.000000
# mean      279.720991
# std         6.215863
# min       231.000000
# 25%       280.500000
# 50%       280.500000
# 75%       280.500000
# max       301.000000
# Name: AVG_MATH_8_SCORE, dtype: float64

# %%
us_data4.describe().AVG_MATH_8_SCORE   #INTERPOLATION
# Out:
# count    1715.000000
# mean      293.025073
# std        12.456644
# min       231.000000
# 25%       285.000000
# 50%       301.000000
# 75%       301.000000
# max       301.000000
# Name: AVG_MATH_8_SCORE, dtype: float64

# %%
us_data2.describe().AVG_READING_4_SCORE    # MEAN
# Out:
# count    1715.000000
# mean      218.166988
# std         4.868461
# min       179.000000
# 25%       218.166988
# 50%       218.166988
# 75%       218.166988
# max       237.000000
# Name: AVG_READING_4_SCORE, dtype: float64

# %%
us_data3.describe().AVG_READING_4_SCORE     # MEDIAN
# Out:
# count    1715.000000
# mean      219.547522
# std         4.762313
# min       179.000000
# 25%       220.000000
# 50%       220.000000
# 75%       220.000000
# max       237.000000
# Name: AVG_READING_4_SCORE, dtype: float64

# %%
us_data4.describe().AVG_READING_4_SCORE      # INTERPOLATION
# Out:
# count    1715.000000
# mean      230.104373
# std        10.014876
# min       179.000000
# 25%       223.000000
# 50%       237.000000
# 75%       237.000000
# max       237.000000
# Name: AVG_READING_4_SCORE, dtype: float64

# %%
us_data2.describe().AVG_READING_8_SCORE    # MEAN
# Out:
# count    1715.000000
# mean      262.953340
# std         3.873393
# min       236.000000
# 25%       262.953340
# 50%       262.953340
# 75%       262.953340
# max       280.000000
# Name: AVG_READING_8_SCORE, dtype: float64

# %%
us_data3.describe().AVG_READING_8_SCORE      # MEDIAN
# Out:
# count    1715.000000
# mean      264.527697
# std         3.843150
# min       236.000000
# 25%       265.000000
# 50%       265.000000
# 75%       265.000000
# max       280.000000
# Name: AVG_READING_8_SCORE, dtype: float64

# %%
us_data4.describe().AVG_READING_8_SCORE    # INTERPOLATION
# Out:
# count    1715.000000
# mean      274.612245
# std         8.596529
# min       236.000000
# 25%       268.000000
# 50%       280.000000
# 75%       280.000000
# max       280.000000
# Name: AVG_READING_8_SCORE, dtype: float64
